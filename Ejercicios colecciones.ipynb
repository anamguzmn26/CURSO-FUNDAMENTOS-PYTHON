# %% [markdown]
# Apropiación Conjuntos

# %% [markdown]
# 3. Se dispone de una lista de códigos de productos que puede contener elementos duplicados. El reto consiste en convertir la lista en una colección que elimine los duplicados, agregar un nuevo producto al conjunto y luego descartar un producto específico. Posteriormente, se compararán dos colecciones (por ejemplo, inventarios de dos almacenes) para identificar los productos comunes, aquellos exclusivos de cada inventario y los que no se repiten entre ambos.

# %%
productos=[106,101,102,103,102,104,105,106,101,104]
conjunto=set(productos)
print(f"Inventario Original:",conjunto)

conjunto.add(107)
print(f"Inventario tras agregar producto 107:",conjunto)

conjunto.discard(103)
print(f"Inventario tras descartar producto 103:",conjunto)

almaA={101, 102, 104, 110}
print(f"\nInventario Almacén A:",almaA)
almaB={102, 104, 107, 110}
print(f"Inventario Almacén B:",almaB)

print(f"Productos comunes: {almaA.intersection(almaB)}")
print(f"Productos exclusivos en Almacén A:  {almaA.difference(almaB)}")
print(f"Productos exclusivos en Almacén B:{almaB.difference(almaA)}")
# Out:
# Inventario Original: {101, 102, 103, 104, 105, 106}
# Inventario tras agregar producto 107: {101, 102, 103, 104, 105, 106, 107}
# Inventario tras descartar producto 103: {101, 102, 104, 105, 106, 107}
#
# Inventario Almacén A: {104, 102, 101, 110}
# Inventario Almacén B: {104, 102, 107, 110}
# Productos comunes: {104, 110, 102}
# Productos exclusivos en Almacén A:  {101}
# Productos exclusivos en Almacén B:{107}

# %% [markdown]
# 4. Dos grupos de amigos tienen colecciones con sus géneros musicales favoritos. Se requiere determinar si ambos grupos comparten al menos un género (evaluar si las colecciones son disjuntas o no). Además, se debe presentar la intersección de géneros, la unión de ambos conjuntos y la diferencia simétrica (los géneros que no coinciden entre los grupos).

# %%
grupA={'rock', 'pop', 'jazz'}
grupB={'pop', 'reggae', 'electrónica'}

print(f"Preferencias Grupo A:",grupA)
print(f"Preferencias Grupo B:",grupB)
print(f"\nGeneros comunes: {grupA.intersection(grupB)}")
print(f"Unión de géneros: {grupA.union(grupB)}")
print(f"Géneros exclusivos (diferencia simétrica): {grupA.symmetric_difference(grupB)}")
# Out:
# Preferencias Grupo A: {'rock', 'jazz', 'pop'}
# Preferencias Grupo B: {'electrónica', 'reggae', 'pop'}
#
# Generos comunes: {'pop'}
# Unión de géneros: {'rock', 'jazz', 'pop', 'electrónica', 'reggae'}
# Géneros exclusivos (diferencia simétrica): {'rock', 'jazz', 'electrónica', 'reggae'}

# %% [markdown]
# Apropiación Diccionarios

# %% [markdown]
# 2. Desarrolla un traductor sencillo que utilice un diccionario donde las claves sean palabras en español y los valores sus traducciones en inglés. El usuario ingresará una palabra en español; si la palabra se encuentra en el diccionario, se mostrará su traducción. En caso contrario, se le solicitará al usuario que proporcione la traducción, la cual se agregará al diccionario. El proceso se repetirá hasta que el usuario decida finalizar la consulta.

# %%
diccionario_principal = {"hola": "hello","mundo": "world","casa": "house"}

print("Diccionario inicial:", diccionario_principal)

palabra = "" 

while palabra != "salir":
    palabra = input("Ingrese una palabra en español: ")

    if palabra == "salir":
        print("Terminando el programa.")
    elif palabra in diccionario_principal:
        print("La traducción de '" + palabra + "' es:", diccionario_principal[palabra])
    else:
        print("La palabra '" + palabra + "' no se encuentra en el diccionario_principal.")
        traduccion = input("Ingrese la traducción de '" + palabra + "': ")
        diccionario_principal[palabra] = traduccion
        print("Nueva entrada agregada: '" + palabra + "': '" + traduccion + "'")
# Out:
# Diccionario inicial: {'hola': 'hello', 'mundo': 'world', 'casa': 'house'}
# La traducción de 'hola' es: hello
# La palabra 'perro' no se encuentra en el diccionario_principal.
# Nueva entrada agregada: 'perro': 'dog'
# La traducción de 'mundo' es: world
# Terminando el programa.

# %% [markdown]
# 3. Crea una aplicación que administre el inventario de una tienda usando un diccionario, donde cada clave representa el nombre de un producto y cada valor la cantidad en stock. La aplicación debe permitir consultar la cantidad de un producto, actualizar el stock de uno existente, agregar nuevos productos y eliminar aquellos que ya no estén disponibles. Al final se mostrará el inventario actualizado.

# %%
inventario = {"manzanas": 50,"naranjas": 30,"peras": 20}

print("Inventario inicial:")
print(inventario)
print("Consulta: ¿Cuántas naranjas hay? ->", inventario["naranjas"])
print("Actualizando stock de peras a 25.")
inventario["peras"] = 25
print('Agregando producto: "bananas" con stock! 40.')
inventario["bananas"] = 40
print('Eliminando producto: "naranjas".')
del inventario["naranjas"]
print("Inventario final:")
print(inventario)
# Out:
# Inventario inicial:
# {'manzanas': 50, 'naranjas': 30, 'peras': 20}
# Consulta: ¿Cuántas naranjas hay? -> 30
# Actualizando stock de peras a 25.
# Agregando producto: "bananas" con stock! 40.
# Eliminando producto: "naranjas".
# Inventario final:
# {'manzanas': 50, 'peras': 25, 'bananas': 40}
